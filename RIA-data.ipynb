# %%
# imports
import pandas as pd

# %%
# load data
df = pd.read_excel('ia110220.xlsx')
print(df.shape)
df.head()
# Out:
# (13847, 262)
#   SEC Region  Organization CRD#       SEC#   Firm Type Umbrella Registration  \
# 0       NYRO                 79   801-3702  Registered                     N
# 1       NYRO                231  801-54739  Registered                     N
# 2       CHRO                728   801-7395  Registered                     N
# 3       CHRO                793  801-10746  Registered                     N
# 4       NYRO                816  801-56264  Registered                     N
#
#                       Primary Business Name  \
# 0                J.P. MORGAN SECURITIES LLC
# 1         BNY MELLON SECURITIES CORPORATION
# 2         ROTHSCHILD INVESTMENT CORPORATION
# 3  STIFEL, NICOLAUS & COMPANY, INCORPORATED
# 4        CREDIT SUISSE SECURITIES (USA) LLC
#
#                                  Legal Name Main Office Street Address 1  \
# 0                J.P. MORGAN SECURITIES LLC              383 MADISON AVE
# ...

# %%
df.describe().T
# Out:
#                                                       count          mean  \
# Organization CRD#                                   13847.0  1.754933e+05
# Total number of offices, other than your Princi...  13811.0  8.398523e+00
# 5A                                                  13845.0  6.649556e+01
# 5B(1)                                               13845.0  3.269679e+01
# 5B(2)                                               13845.0  2.840621e+01
# 5B(3)                                               13845.0  2.327136e+01
# 5B(4)                                               13845.0  1.465294e+00
# 5B(5)                                               13845.0  1.819350e+01
# 5B(6)                                               13845.0  2.425121e+01
# 5C(1)-If more than 100, how many                       36.0  2.138889e+02
# 5C(2)                                               13845.0  1.377494e+01
# 5D(1)(m)-Other                                          0.0           NaN
# ...

# %%
# TODO - try to convert columns with s
